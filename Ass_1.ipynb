# %% [markdown]
# <a href="https://colab.research.google.com/github/Saniaa2715/DSDBA/blob/main/Ass_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import all the required Python Libraries.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the Dataset into pandas dataframe.

df=pd.read_csv("/content/Weather_Data.csv")

# %%
df
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2/1/2008     19.5     22.4      15.6          6.2       0.0
# 1      2/2/2008     19.5     25.6       6.0          3.4       2.7
# 2      2/3/2008     21.6     24.5       6.6          2.4       0.1
# 3      2/4/2008     20.2     22.8      18.8          2.2       0.0
# 4      2/5/2008     19.7     25.7      77.4          4.8       0.0
# ...         ...      ...      ...       ...          ...       ...
# 3266  6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267  6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268  6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269  6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270  6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              W             41          S        SSW  ...           92
# ...

# %%
df.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.tail()
# Out:
#            Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 3266  6/21/2017      8.6     19.6       0.0          2.0       7.8
# 3267  6/22/2017      9.3     19.2       0.0          2.0       9.2
# 3268  6/23/2017      9.4     17.7       0.0          2.4       2.7
# 3269  6/24/2017     10.1     19.3       0.0          1.4       9.3
# 3270  6/25/2017      7.6     19.3       0.0          3.4       9.4
#
#      WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 3266         SSE             37          W        SSE  ...           73
# 3267           W             30          W        ESE  ...           78
# 3268           W             24        WNW          N  ...           85
# 3269           W             43          W          W  ...           56
# 3270           W             35          W          W  ...           73
#
#       Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# ...

# %%
df.describe()
# Out:
#            MinTemp      MaxTemp     Rainfall  Evaporation     Sunshine  \
# count  3271.000000  3271.000000  3271.000000  3271.000000  3271.000000
# mean     14.877102    23.005564     3.342158     5.175787     7.168970
# std       4.554710     4.483752     9.917746     2.757684     3.815966
# min       4.300000    11.700000     0.000000     0.000000     0.000000
# 25%      11.000000    19.600000     0.000000     3.200000     4.250000
# 50%      14.900000    22.800000     0.000000     4.800000     8.300000
# 75%      18.800000    26.000000     1.400000     7.000000    10.200000
# max      27.600000    45.800000   119.400000    18.400000    13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count    3271.000000   3271.000000   3271.000000  3271.000000  3271.000000
# mean       41.476307     15.077041     19.294405    68.243962    54.698563
# std        10.806951      7.043825      7.453331    15.086127    16.279241
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3271 entries, 0 to 3270
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           3271 non-null   object
#  1   MinTemp        3271 non-null   float64
#  2   MaxTemp        3271 non-null   float64
#  3   Rainfall       3271 non-null   float64
#  4   Evaporation    3271 non-null   float64
#  5   Sunshine       3271 non-null   float64
#  6   WindGustDir    3271 non-null   object
#  7   WindGustSpeed  3271 non-null   int64
#  8   WindDir9am     3271 non-null   object
#  9   WindDir3pm     3271 non-null   object
#  10  WindSpeed9am   3271 non-null   int64
#  11  WindSpeed3pm   3271 non-null   int64
#  12  Humidity9am    3271 non-null   int64
#  13  Humidity3pm    3271 non-null   int64
#  14  Pressure9am    3271 non-null   float64
#  15  Pressure3pm    3271 non-null   float64
#  16  Cloud9am       3271 non-null   int64
# ...

# %%
# Check the dimensions of the data frame

df.shape
# Out:
# (3271, 22)

# %%
df.columns
# Out:
# Index(['Date', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine',
#        'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
# Data Preprocessing

df.dtypes
# Out:
# Date              object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed      int64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am       int64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Date             0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
# Turn categorical variables into quantitative variables in Python

from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()

df['Rain_Tomorrow_Encoded'] = lb.fit_transform(df['RainTomorrow'])

# %%
df['RainTomorrow']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 3266     No
# 3267     No
# 3268     No
# 3269     No
# 3270     No
# Name: RainTomorrow, Length: 3271, dtype: object

# %%
df['Rain_Tomorrow_Encoded']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3266    0
# 3267    0
# 3268    0
# 3269    0
# 3270    0
# Name: Rain_Tomorrow_Encoded, Length: 3271, dtype: int64
